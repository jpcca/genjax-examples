# %%
import pandas as pd
from utils.plot import analyze_referer_influence, plot_referer_heatmaps

data = pd.read_csv("../tests/data/1-example/train.csv")

# Analyze referer influence and get top referers
filtered_df, scores, top_referers = analyze_referer_influence(data, top_n=10, min_count=100)

# %%
# Heatmaps of top referers
plot_referer_heatmaps(filtered_df, top_referers)
